# %%
# Python is a case sensitive language
print('Hello World!!')
# Out:
# Hello World!!

# %%
print('Hello', 1, 4.5, True)
# Out:
# Hello 1 4.5 True

# %%
print('Hello', 1, 4.5, True, sep='/')
# Out:
# Hello/1/4.5/True

# %%
print('Hello')
print('World!!')
# Out:
# Hello
# World!!

# %%
print('Hello', end='-')
print('World!!')
# Out:
# Hello-World!!
