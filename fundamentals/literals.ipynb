# %%
# Binary Literal
a = 0b1010
print(a)
# Out:
# 10

# %%
# Decimal Literal
b = 100
print(b)
# Out:
# 100

# %%
# Complex Literal
x = 3.14j
print(x.real, x.imag)
# Out:
# 0.0 3.14

# %%
# None Literal
a = None
print(a)
# Out:
# None
