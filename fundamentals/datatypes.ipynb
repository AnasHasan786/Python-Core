# %%
# Integer
print(8)
print(1e308)
# Out:
# 8
# 1e+308

# %%
# Decimal/Float
print(8.55)
print(1.7e308)
# Out:
# 8.55
# 1.7e+308

# %%
# Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
# Text/String
print('Hello World!!')
# Out:
# Hello World!!

# %%
# Complex
print(5+6j)
# Out:
# (5+6j)

# %%
# List
print([1, 2, 3, 4, 5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# Tuple
print((1, 2, 3, 4, 5))
# Out:
# (1, 2, 3, 4, 5)

# %%
# Sets
print({1, 2, 3, 4, 5})
# Out:
# {1, 2, 3, 4, 5}

# %%
# Dictionary
print({'Name': 'Anas', 'Gender': 'M'})
# Out:
# {'Name': 'Anas', 'Gender': 'M'}

# %%
# Type function
type('Hello')
# Out:
# str
