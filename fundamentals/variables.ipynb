# %%
name = 'Anas'
print(name)
# Out:
# Anas

# %%
a = 5
b = 6
print(a + b)
# Out:
# 11

# %%
# Dynamic Binding
a = 5
print(a)
a = 'Nitish'
print(a)

# Static Binding
# int a = 5;
# Out:
# 5
# Nitish

# %%
a = 1
b = 2
c = 3
print(a, b, c)
# Out:
# 1 2 3

# %%
a, b, c = 1, 2, 3
print(a, b, c)
# Out:
# 1 2 3

# %%
a = b = c = 5
print(a, b, c)
# Out:
# 5 5 5
